# %%
# pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\sharm\anaconda3\lib\site-packages (0.3.12)
# Requirement already satisfied: packaging in c:\users\sharm\anaconda3\lib\site-packages (from kagglehub) (23.2)
# Requirement already satisfied: pyyaml in c:\users\sharm\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\sharm\anaconda3\lib\site-packages (from kagglehub) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\sharm\anaconda3\lib\site-packages (from kagglehub) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sharm\anaconda3\lib\site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sharm\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sharm\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sharm\anaconda3\lib\site-packages (from requests->kagglehub) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\sharm\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("manishkr1754/cardekho-used-car-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\sharm\.cache\kagglehub\datasets\manishkr1754\cardekho-used-car-data\versions\2

# %%
import os
all_files = os.listdir(path)
all_files
# Out:
# ['cardekho_dataset.csv']

# %%
file_path = path +'\\'+all_files[0]
file_path
# Out:
# 'C:\\Users\\sharm\\.cache\\kagglehub\\datasets\\manishkr1754\\cardekho-used-car-data\\versions\\2\\cardekho_dataset.csv'

# %%
import pandas as pd
df = pd.read_csv(file_path)
print('File Loaded Successfully')
# Out:
# File Loaded Successfully

# %%
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.tail()
# Out:
#        Unnamed: 0         car_name     brand   model  vehicle_age  km_driven  \
# 15406       19537      Hyundai i10   Hyundai     i10            9      10723
# 15407       19540    Maruti Ertiga    Maruti  Ertiga            2      18000
# 15408       19541      Skoda Rapid     Skoda   Rapid            6      67000
# 15409       19542  Mahindra XUV500  Mahindra  XUV500            5    3800000
# 15410       19543       Honda City     Honda    City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 15406      Dealer    Petrol            Manual    19.81    1086      68.05
# 15407      Dealer    Petrol            Manual    17.50    1373      91.10
# 15408      Dealer    Diesel            Manual    21.14    1498     103.52
# 15409      Dealer    Diesel            Manual    16.00    2179     140.00
# 15410      Dealer    Petrol         Automatic    18.00    1497     117.60
#
#        seats  selling_price
# 15406      5         250000
# 15407      7         925000
# 15408      5         425000
# 15409      7        1225000
# 15410      5        1200000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  object
#  7   fuel_type          15411 non-null  object
#  8   transmission_type  15411 non-null  object
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 1.6+ MB

# %%
r,c = df.shape
print(f'''Dataset contains
Rows: {r}
Columns: {c}''') #Wrangling to clean data
# Out:
# Dataset contains
# Rows: 15411
# Columns: 14

# %%
#Data mungin
#data wrangling

# %%
#list of columns
df.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
#        'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
#        'max_power', 'seats', 'selling_price'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# 1      Individual    Petrol            Manual    18.90    1197      82.00
# 2      Individual    Petrol            Manual    17.00    1197      80.00
# 3      Individual    Petrol            Manual    20.92     998      67.10
# 4          Dealer    Diesel            Manual    22.77    1498      98.59
# ...           ...       ...               ...      ...     ...        ...
# 15406      Dealer    Petrol            Manual    19.81    1086      68.05
# 15407      Dealer    Petrol            Manual    17.50    1373      91.10
# 15408      Dealer    Diesel            Manual    21.14    1498     103.52
# 15409      Dealer    Diesel            Manual    16.00    2179     140.00
# 15410      Dealer    Petrol         Automatic    18.00    1497     117.60
#
#        seats  selling_price
# 0          5         120000
# 1          5         550000
# 2          5         215000
# 3          5         226000
# 4          5         570000
# ...      ...            ...
# 15406      5         250000
# 15407      7         925000
# 15408      5         425000
# 15409      7        1225000
# 15410      5        1200000
#
# [15411 rows x 13 columns]

# %%
df.sample(3)
# Out:
#             car_name   brand   model  vehicle_age  km_driven  \
# 12634     Honda City   Honda    City            7      80633
# 5471   Maruti Baleno  Maruti  Baleno            4      43000
# 10398  Maruti Baleno  Maruti  Baleno            5      60201
#
#             seller_type fuel_type transmission_type  mileage  engine  \
# 12634            Dealer    Diesel            Manual    26.00    1498
# 5471         Individual    Petrol            Manual    21.40    1197
# 10398  Trustmark Dealer    Petrol            Manual    21.01    1197
#
#        max_power  seats  selling_price
# 12634       98.6      5         575000
# 5471        83.1      5         625000
# 10398       81.8      5         490000

# %%
df.index #it will check index range
# Out:
# RangeIndex(start=0, stop=15411, step=1)

# %%
#missing value
df.isna().sum() #zero represent no null value found
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
#graph/visuals : heatmap

import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#Missing values:
#Replace/Fill/Remove/Ignore

# %%
#stats:bydefault: numerical(): Ignore: object/category
df.describe().round(2)
# Out:
#        vehicle_age   km_driven   mileage    engine  max_power     seats  \
# count     15411.00    15411.00  15411.00  15411.00   15411.00  15411.00
# mean          6.04    55616.48     19.70   1486.06     100.59      5.33
# std           3.01    51618.55      4.17    521.11      42.97      0.81
# min           0.00      100.00      4.00    793.00      38.40      0.00
# 25%           4.00    30000.00     17.00   1197.00      74.00      5.00
# 50%           6.00    50000.00     19.67   1248.00      88.50      5.00
# 75%           8.00    70000.00     22.70   1582.00     117.30      5.00
# max          29.00  3800000.00     33.54   6592.00     626.00      9.00
#
#        selling_price
# count       15411.00
# mean       774971.12
# std        894128.36
# min         40000.00
# 25%        385000.00
# 50%        556000.00
# 75%        825000.00
# max      39500000.00

# %%
df.describe(include = ['O'])
# Out:
#            car_name   brand  model seller_type fuel_type transmission_type
# count         15411   15411  15411       15411     15411             15411
# unique          121      32    120           3         5                 2
# top     Hyundai i20  Maruti    i20      Dealer    Petrol            Manual
# freq            906    4992    906        9539      7643             12225

# %%
#Finding
# Car dekho website has most demanded model i20 freq:906

# %%
#Analysis
# Univariate, Bivariate and Multivariate data and its analysis
# Univariate: Single column
# Bivariante: Double column
# Multivariate: more than 2 column

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %% [markdown]
# # Univariate

# %%
cat_col = list(df.describe(include=['O']).columns)
num_col = list(df.describe().columns)

# %%
print(cat_col)
# Out:
# ['car_name', 'brand', 'model', 'seller_type', 'fuel_type', 'transmission_type']

# %%
print(num_col)
# Out:
# ['vehicle_age', 'km_driven', 'mileage', 'engine', 'max_power', 'seats', 'selling_price']

# %%
# unique, nunique, value_counts

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#series : single col(series)

# %%
print(type(df['car_name']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['car_name'].value_counts().head(10) #it tells number of car available
# Out:
# car_name
# Hyundai i20           906
# Maruti Swift Dzire    890
# Maruti Swift          781
# Maruti Alto           778
# Honda City            757
# Maruti Wagon R        717
# Hyundai Grand         580
# Toyota Innova         545
# Hyundai Verna         492
# Hyundai i10           410
# Name: count, dtype: int64

# %%
df['car_name'].value_counts().tail(10)
# Out:
# car_name
# Maruti Dzire LXI         2
# Isuzu MUX                1
# Maserati Quattroporte    1
# Rolls-Royce Ghost        1
# Maserati Ghibli          1
# Mercedes-AMG C           1
# Tata Altroz              1
# Ferrari GTC4Lusso        1
# Hyundai Aura             1
# Force Gurkha             1
# Name: count, dtype: int64

# %%
# Top 10 Analysis For Categorial Column

for i in cat_col:
    print(f'\n\nTop 10 Analysis by {i}\n')
    top_10 = df[i].value_counts().head(10)
    ans = (top_10/top_10.sum())*100

    display(ans.round(2))
# Out:
# Top 10 Analysis by car_name
# car_name
# Hyundai i20           13.21
# Maruti Swift Dzire    12.98
# Maruti Swift          11.39
# Maruti Alto           11.35
# Honda City            11.04
# Maruti Wagon R        10.46
# Hyundai Grand          8.46
# Toyota Innova          7.95
# Hyundai Verna          7.18
# Hyundai i10            5.98
# Name: count, dtype: float64
# Top 10 Analysis by brand
# brand
# Maruti        35.46
# Hyundai       21.18
# Honda         10.55
# Mahindra       7.18
# Toyota         5.63
# Ford           5.61
# Volkswagen     4.40
# Renault        3.81
# BMW            3.12
# Tata           3.05
# Name: count, dtype: float64
# Top 10 Analysis by model
# model
# i20            13.21
# Swift Dzire    12.98
# Swift          11.39
# Alto           11.35
# City           11.04
# Wagon R        10.46
# Grand           8.46
# Innova          7.95
# Verna           7.18
# i10             5.98
# Name: count, dtype: float64
# Top 10 Analysis by seller_type
# seller_type
# Dealer              61.90
# Individual          36.98
# Trustmark Dealer     1.12
# Name: count, dtype: float64
# Top 10 Analysis by fuel_type
# fuel_type
# Petrol      49.59
# Diesel      48.14
# CNG          1.95
# LPG          0.29
# Electric     0.03
# Name: count, dtype: float64
# Top 10 Analysis by transmission_type
# transmission_type
# Manual       79.33
# Automatic    20.67
# Name: count, dtype: float64

# %%
top_10_series = df['car_name'].value_counts().head(10)
(top_10_series/top_10_series.sum())*100
# Out:
# car_name
# Hyundai i20           13.214702
# Maruti Swift Dzire    12.981330
# Maruti Swift          11.391482
# Maruti Alto           11.347725
# Honda City            11.041424
# Maruti Wagon R        10.457993
# Hyundai Grand          8.459743
# Toyota Innova          7.949242
# Hyundai Verna          7.176196
# Hyundai i10            5.980163
# Name: count, dtype: float64

# %%
top_10_series = df['car_name'].value_counts().head(10)
(top_10_series/r)*100
# Out:
# car_name
# Hyundai i20           5.878918
# Maruti Swift Dzire    5.775096
# Maruti Swift          5.067809
# Maruti Alto           5.048342
# Honda City            4.912076
# Maruti Wagon R        4.652521
# Hyundai Grand         3.763546
# Toyota Innova         3.536435
# Hyundai Verna         3.192525
# Hyundai i10           2.660437
# Name: count, dtype: float64

# %%
# Bottom 10 Analysis For Categorial Column

for i in cat_col:
    print(f'\n\nBottom 10 Analysis by {i}\n')
    Bottom_10 = df[i].value_counts().tail(10)
    

    display(Bottom_10)
# Out:
# Bottom 10 Analysis by car_name
# car_name
# Maruti Dzire LXI         2
# Isuzu MUX                1
# Maserati Quattroporte    1
# Rolls-Royce Ghost        1
# Maserati Ghibli          1
# Mercedes-AMG C           1
# Tata Altroz              1
# Ferrari GTC4Lusso        1
# Hyundai Aura             1
# Force Gurkha             1
# Name: count, dtype: int64
# Bottom 10 Analysis by brand
# brand
# Nissan          11
# Lexus           10
# Isuzu            8
# Bentley          3
# Maserati         2
# ISUZU            2
# Ferrari          1
# Mercedes-AMG     1
# Rolls-Royce      1
# Force            1
# Name: count, dtype: int64
# Bottom 10 Analysis by model
# model
# NX              2
# Dzire LXI       2
# Quattroporte    1
# Ghost           1
# C               1
# Ghibli          1
# Altroz          1
# GTC4Lusso       1
# Aura            1
# Gurkha          1
# Name: count, dtype: int64
# Bottom 10 Analysis by seller_type
# seller_type
# Dealer              9539
# Individual          5699
# Trustmark Dealer     173
# Name: count, dtype: int64
# Bottom 10 Analysis by fuel_type
# fuel_type
# Petrol      7643
# Diesel      7419
# CNG          301
# LPG           44
# Electric       4
# Name: count, dtype: int64
# Bottom 10 Analysis by transmission_type
# transmission_type
# Manual       12225
# Automatic     3186
# Name: count, dtype: int64

# %%
df['car_name'].value_counts().head(10).plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

def graph_plot(col_name):

    x = df[col_name].value_counts().head(10).index
    y = df[col_name].value_counts().head(10).values
    
    plt.figure(figsize =(8,4))
    plt.title(f'Top 10 {col_name} by Inventory',fontsize = 20,color = 'Brown')
    # ax = plt.bar(x,y,color = 'pink')
    ax = plt.bar(x,y,color = sns.color_palette('magma',10))
    plt.bar_label(ax)
    plt.xticks(rotation = 45)
    plt.show()

# %%
for i in cat_col:
    graph_plot(i)

# %%
num_col
# Out:
# ['vehicle_age',
#  'km_driven',
#  'mileage',
#  'engine',
#  'max_power',
#  'seats',
#  'selling_price']

# %%
df['selling_price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np
def plot_hist(col_name,bin_size = 100):
    plt.title(f'\n\n{col_name} Distribution Analysis'.title(),fontsize = 20,color = 'Red')
    plt.hist(df[col_name],color = 'red',bins = np.linspace(df[col_name].min(),df[col_name].max(),bin_size))
    plt.show()

# %%
plot_hist('engine')

# %%
for i in num_col:
    plot_hist(i)

# %%
# How to Filter Dataframe
# Masking Technique

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df['mileage'].min()
# Out:
# 4.0

# %%
df[df['mileage'] == df['mileage'].min()]
# Out:
#                car_name    brand      model  vehicle_age  km_driven  \
# 3799  Ferrari GTC4Lusso  Ferrari  GTC4Lusso            2       3800
#
#      seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 3799      Dealer    Petrol         Automatic      4.0    3855      601.0
#
#       seats  selling_price
# 3799      4       39500000

# %%
df[df['mileage'] == df['mileage'].max()]
# Out:
#              car_name   brand    model  vehicle_age  km_driven  \
# 169    Maruti Wagon R  Maruti  Wagon R            3      52000
# 182    Maruti Wagon R  Maruti  Wagon R            8      64000
# 1250   Maruti Wagon R  Maruti  Wagon R            4      32013
# 1574   Maruti Wagon R  Maruti  Wagon R            6      55000
# 2271   Maruti Wagon R  Maruti  Wagon R            9      62000
# 2303   Maruti Wagon R  Maruti  Wagon R            7     135975
# 2364   Maruti Wagon R  Maruti  Wagon R            8      63000
# 2750   Maruti Wagon R  Maruti  Wagon R            8      55853
# 2925   Maruti Wagon R  Maruti  Wagon R            3      32000
# 3342   Maruti Wagon R  Maruti  Wagon R            5      64224
# 3743   Maruti Wagon R  Maruti  Wagon R            7      69000
# 6989   Maruti Wagon R  Maruti  Wagon R            6      69000
# 9193   Maruti Wagon R  Maruti  Wagon R            2      19022
# 9483   Maruti Wagon R  Maruti  Wagon R            3      33955
# 9908   Maruti Wagon R  Maruti  Wagon R            5      37208
# 9960   Maruti Wagon R  Maruti  Wagon R            3      55000
# 10303  Maruti Wagon R  Maruti  Wagon R            9      71000
# 10361  Maruti Wagon R  Maruti  Wagon R            4      75000
# 11310  Maruti Wagon R  Maruti  Wagon R            5      65000
# 11685  Maruti Wagon R  Maruti  Wagon R            4      28763
# 11727  Maruti Wagon R  Maruti  Wagon R            4      30000
# 12260  Maruti Wagon R  Maruti  Wagon R            5      56000
# 12696  Maruti Wagon R  Maruti  Wagon R            5      53000
# 15226  Maruti Wagon R  Maruti  Wagon R            5      74844
#
#             seller_type fuel_type transmission_type  mileage  engine  \
# 169              Dealer       CNG            Manual    33.54     998
# 182              Dealer       CNG            Manual    33.54     998
# 1250   Trustmark Dealer       CNG            Manual    33.54     998
# 1574             Dealer       CNG            Manual    33.54     998
# 2271             Dealer       CNG            Manual    33.54     998
# 2303             Dealer       CNG            Manual    33.54     998
# 2364             Dealer       CNG            Manual    33.54     998
# 2750             Dealer       CNG            Manual    33.54     998
# 2925             Dealer       CNG            Manual    33.54     998
# 3342             Dealer       CNG            Manual    33.54     998
# 3743             Dealer       CNG            Manual    33.54     998
# 6989             Dealer       CNG            Manual    33.54     998
# 9193             Dealer       CNG            Manual    33.54     998
# 9483   Trustmark Dealer       CNG            Manual    33.54     998
# 9908   Trustmark Dealer       CNG            Manual    33.54     998
# 9960             Dealer       CNG            Manual    33.54     998
# 10303            Dealer       CNG            Manual    33.54     998
# 10361            Dealer       CNG            Manual    33.54     998
# 11310            Dealer       CNG            Manual    33.54     998
# 11685  Trustmark Dealer       CNG            Manual    33.54     998
# 11727        Individual       CNG            Manual    33.54     998
# 12260            Dealer       CNG            Manual    33.54     998
# 12696            Dealer       CNG            Manual    33.54     998
# 15226            Dealer       CNG            Manual    33.54     998
#
#        max_power  seats  selling_price
# 169        67.04      5         435000
# 182        67.04      5         270000
# 1250       67.04      5         380000
# 1574       67.04      5         335000
# 2271       67.04      5         340000
# 2303       67.04      5         295000
# 2364       67.04      5         351000
# 2750       67.04      5         349000
# 2925       67.04      5         485000
# 3342       67.04      5         375000
# 3743       67.04      5         349000
# 6989       67.04      5         350000
# 9193       67.04      5         470000
# 9483       67.04      5         425000
# 9908       67.04      5         365000
# 9960       67.04      5         380000
# 10303      67.04      5         275000
# 10361      67.04      5         375000
# 11310      67.04      5         310000
# 11685      67.04      5         400000
# 11727      67.04      5         450000
# 12260      67.04      5         360000
# 12696      67.04      5         380000
# 15226      67.04      5         390000

# %%
df[df['km_driven'] == df['km_driven'].max()]
# Out:
#               car_name     brand   model  vehicle_age  km_driven seller_type  \
# 15409  Mahindra XUV500  Mahindra  XUV500            5    3800000      Dealer
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# 15409    Diesel            Manual     16.0    2179      140.0      7
#
#        selling_price
# 15409        1225000

# %%
df[df['selling_price'] == df['selling_price'].max()]
# Out:
#                car_name    brand      model  vehicle_age  km_driven  \
# 3799  Ferrari GTC4Lusso  Ferrari  GTC4Lusso            2       3800
#
#      seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 3799      Dealer    Petrol         Automatic      4.0    3855      601.0
#
#       seats  selling_price
# 3799      4       39500000

# %%
df[df['selling_price'] == df['selling_price'].min()]
# Out:
#             car_name   brand    model  vehicle_age  km_driven seller_type  \
# 7607  Maruti Wagon R  Maruti  Wagon R           21      80000  Individual
#
#      fuel_type transmission_type  mileage  engine  max_power  seats  \
# 7607    Petrol            Manual     18.9     998       67.1      5
#
#       selling_price
# 7607          40000

# %%
second_min_price = df['selling_price'].sort_values().values[1]

# %%
df[df['selling_price'] == second_min_price]
# Out:
#           car_name   brand model  vehicle_age  km_driven seller_type  \
# 13676  Maruti Alto  Maruti  Alto           17     110000  Individual
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# 13676    Petrol            Manual     19.7     796       46.3      5
#
#        selling_price
# 13676          45000

# %%
second_costly_price = df['selling_price'].sort_values(ascending = False).values[1]

# %%
df[df['selling_price'] == second_costly_price]
# Out:
#                 car_name        brand  model  vehicle_age  km_driven  \
# 10969  Rolls-Royce Ghost  Rolls-Royce  Ghost            4       5000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 10969  Individual    Petrol         Automatic     10.2    6592      563.0
#
#        seats  selling_price
# 10969      4       24200000

# %%
# Top 10 cars by selling price

top_10_sp_df = df.sort_values(by = 'selling_price',ascending = False).head(10)

# %%
top_10_sp_df[['car_name','vehicle_age','fuel_type','selling_price']]
# Out:
#                     car_name  vehicle_age fuel_type  selling_price
# 3799       Ferrari GTC4Lusso            2    Petrol       39500000
# 10969      Rolls-Royce Ghost            4    Petrol       24200000
# 1172     Bentley Continental            9    Petrol       14500000
# 9722   Mercedes-Benz S-Class            3    Petrol       13000000
# 9364         Porsche Cayenne            4    Petrol       11100000
# 10989  Mercedes-Benz S-Class            2    Petrol       11000000
# 1888   Mercedes-Benz S-Class            5    Petrol       11000000
# 11000       Land Rover Rover            4    Diesel        9200000
# 8439                   BMW 7            3    Diesel        8500000
# 3096                   BMW 7            3    Diesel        8500000

# %%
# Top 10 cars by vehicle age

top_10_va_df = df.sort_values(by = 'vehicle_age',ascending = False).head(10)

# %%
top_10_va_df[['car_name','vehicle_age','fuel_type','selling_price']]
# Out:
#              car_name  vehicle_age fuel_type  selling_price
# 2596      Maruti Alto           29    Petrol          60000
# 15329           BMW 3           25    Petrol        1000000
# 14317      Honda City           22    Petrol          70000
# 8146   Maruti Wagon R           21    Petrol          95000
# 6660   Maruti Wagon R           21    Petrol          85000
# 7607   Maruti Wagon R           21    Petrol          40000
# 6539      Maruti Alto           19    Petrol         100000
# 8000   Maruti Wagon R           19    Petrol          80000
# 3787      Maruti Alto           19    Petrol          50000
# 7687      Maruti Alto           19    Petrol          90000

# %%
df['brand'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Ford', 'Renault', 'Mini', 'Mercedes-Benz',
#        'Toyota', 'Volkswagen', 'Honda', 'Mahindra', 'Datsun', 'Tata',
#        'Kia', 'BMW', 'Audi', 'Land Rover', 'Jaguar', 'MG', 'Isuzu',
#        'Porsche', 'Skoda', 'Volvo', 'Lexus', 'Jeep', 'Maserati',
#        'Bentley', 'Nissan', 'ISUZU', 'Ferrari', 'Mercedes-AMG',
#        'Rolls-Royce', 'Force'], dtype=object)

# %%
df['brand'].nunique()
# Out:
# 32

# %%
#group by

df.groupby('brand')['selling_price'].mean().round(2).sort_values(ascending = 0)
# Out:
# brand
# Ferrari          39500000.00
# Rolls-Royce      24200000.00
# Bentley           9266666.67
# Maserati          6100000.00
# Porsche           5161190.48
# Lexus             5146500.00
# Mercedes-AMG      5100000.00
# Land Rover        3823901.96
# Volvo             3729700.00
# BMW               2693826.88
# Jaguar            2643033.90
# Mercedes-Benz     2480741.84
# Mini              2182647.06
# Audi              1966864.58
# ISUZU             1897500.00
# Jeep              1795804.88
# MG                1752947.37
# Kia               1735250.00
# Toyota            1371316.52
# Isuzu             1355000.00
# Nissan             955363.64
# Mahindra           787455.00
# Skoda              784089.82
# Force              700000.00
# Tata               683534.88
# Ford               645224.05
# Honda              617756.90
# Hyundai            576153.92
# Volkswagen         516546.77
# Maruti             487089.32
# Renault            440985.07
# Datsun             320517.65
# Name: selling_price, dtype: float64

# %%
 df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df.groupby('seller_type')['selling_price'].agg(['min','max','mean']).round(2)
# Out:
#                      min       max       mean
# seller_type
# Dealer             55000  39500000  872505.50
# Individual         40000  24200000  617880.48
# Trustmark Dealer  210000   1575000  571959.54
