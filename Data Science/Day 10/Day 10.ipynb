# %%
#split
#where
#clip
#broadcasting
#Panda Function

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r'C:\Users\sharm\OneDrive\Pictures\Saved Pictures\minions.jpg')
arr
# Out:
# array([[[ 77, 156, 223],
#         [ 77, 156, 223],
#         [ 77, 156, 223],
#         ...,
#         [ 79, 158, 225],
#         [ 79, 158, 225],
#         [ 79, 158, 225]],
#
#        [[ 77, 156, 223],
#         [ 77, 156, 223],
#         [ 77, 156, 223],
#         ...,
#         [ 79, 158, 225],
#         [ 79, 158, 225],
#         [ 79, 158, 225]],
#
#        [[ 77, 156, 223],
#         [ 77, 156, 223],
#         [ 77, 156, 223],
#         ...,
#         [ 79, 158, 225],
#         [ 79, 158, 225],
#         [ 79, 158, 225]],
#
#        ...,
#
#        [[221, 226, 246],
#         [221, 226, 246],
#         [221, 226, 246],
#         ...,
#         [251, 225, 128],
#         [251, 225, 128],
#         [251, 225, 128]],
#
#        [[220, 225, 245],
#         [220, 225, 245],
#         [220, 225, 245],
#         ...,
#         [251, 225, 128],
#         [251, 225, 128],
#         [251, 225, 128]],
#
#        [[220, 225, 245],
#         [220, 225, 245],
#         [220, 225, 245],
#         ...,
#         [251, 225, 128],
#         [251, 225, 128],
#         [251, 225, 128]]], dtype=uint8)

# %%
mini_arr = arr.copy()

# %%
plt.imshow(mini_arr)

# %%
mini_arr.shape
# Out:
# (1200, 1920, 3)

# %%
a = np.random.randint(0,255,(3,3,3))
plt.imshow(a)

# %%
while True:
    import numpy as np
    import matplotlib.pyplot as plt
    import time
    a = np.random.randint(0,255,(5,5,3))
    plt.imshow(a)
    plt.show()
    time.sleep(0.3)
    display(clear = True)

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[115,  42, 159],
#         [ 57, 175,  39],
#         [ 59,  58, 221],
#         [144,  39, 219]],
#
#        [[249, 243, 220],
#         [168,  34, 177],
#         [108, 191, 139],
#         [  9, 231, 200]],
#
#        [[ 33, 156,  17],
#         [245, 161,  80],
#         [159,  88,  43],
#         [145,  73, 149]],
#
#        [[241,  38, 189],
#         [246,  89,  15],
#         [107, 180, 117],
#         [242,   3, 185]]])

# %%
final_arr = np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(final_arr[0])

# %%
plt.imshow(final_arr[1])

# %%
a1 = np.split(a,2, axis = 1)

# %%
len(a1)
# Out:
# 2

# %%
a1
# Out:
# [array([[[115,  42, 159],
#          [ 57, 175,  39]],
#
#         [[249, 243, 220],
#          [168,  34, 177]],
#
#         [[ 33, 156,  17],
#          [245, 161,  80]],
#
#         [[241,  38, 189],
#          [246,  89,  15]]]),
#  array([[[ 59,  58, 221],
#          [144,  39, 219]],
#
#         [[108, 191, 139],
#          [  9, 231, 200]],
#
#         [[159,  88,  43],
#          [145,  73, 149]],
#
#         [[107, 180, 117],
#          [242,   3, 185]]])]

# %%
a.shape
# Out:
# (4, 4, 3)

# %%
a_3_part = np.split(a,3,axis = 2)
a_3_part
# Out:
# [array([[[115],
#          [ 57],
#          [ 59],
#          [144]],
#
#         [[249],
#          [168],
#          [108],
#          [  9]],
#
#         [[ 33],
#          [245],
#          [159],
#          [145]],
#
#         [[241],
#          [246],
#          [107],
#          [242]]]),
#  array([[[ 42],
#          [175],
#          [ 58],
#          [ 39]],
#
#         [[243],
#          [ 34],
#          [191],
#          [231]],
#
#         [[156],
#          [161],
#          [ 88],
#          [ 73]],
#
#         [[ 38],
#          [ 89],
#          [180],
#          [  3]]]),
#  array([[[159],
#          [ 39],
#          [221],
#          [219]],
#
#         [[220],
#          [177],
#          [139],
#          [200]],
#
#         [[ 17],
#          [ 80],
#          [ 43],
#          [149]],
#
#         [[189],
#          [ 15],
#          [117],
#          [185]]])]

# %%
plt.imshow(a)

# %%
len(a_3_part)
# Out:
# 3

# %%
plt.imshow(a_3_part[0])

# %%
plt.imshow(a_3_part[1])

# %%
plt.imshow(a_3_part[2])

# %%
mini_arr.shape
# Out:
# (1200, 1920, 3)

# %%
plt.imshow(np.split(mini_arr,3,axis = 2)[2])

# %%
plt.imshow(np.split(mini_arr,2,axis = 0)[0])

# %%
plt.imshow(np.split(mini_arr,2,axis = 0)[1])

# %%
1920//3
# Out:
# 640

# %%
plt.imshow(mini_arr[:,:640,:])

# %%
plt.imshow(mini_arr[:,640:640*2,:])

# %%
plt.imshow(mini_arr[:,640*2:640*3:,:])

# %%
a = np.random.randint(1,500,(4,4))
a
# Out:
# array([[231, 473, 479, 498],
#        [459, 324,  73, 433],
#        [271, 186, 288, 305],
#        [ 19, 186, 322, 406]])

# %%
np.where(a>200,'High Sales',a)
# Out:
# array([['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['High Sales', 'High Sales', '73', 'High Sales'],
#        ['High Sales', '186', 'High Sales', 'High Sales'],
#        ['19', '186', 'High Sales', 'High Sales']], dtype='<U11')

# %%
a
# Out:
# array([[231, 473, 479, 498],
#        [459, 324,  73, 433],
#        [271, 186, 288, 305],
#        [ 19, 186, 322, 406]])

# %%
np.clip(a,100,250) #outliers remove/replace
# Out:
# array([[231, 250, 250, 250],
#        [250, 250, 100, 250],
#        [250, 186, 250, 250],
#        [100, 186, 250, 250]])

# %% [markdown]
# # Broadcasting

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,7))
print(a)
print('-------\n\n')
print(b)
# Out:
# [7 8 2 5 5 8 3]
# -------
#
#
# [[7 9 8 1 4 5 9]
#  [6 5 8 3 8 3 9]]

# %%
a+b
# Out:
# array([[14, 17, 10,  6,  9, 13, 12],
#        [13, 13, 10,  8, 13, 11, 12]])

# %%
a*b
# Out:
# array([[49, 72, 16,  5, 20, 40, 27],
#        [42, 40, 16, 15, 40, 24, 27]])

# %%
a = np.random.randint(1,10,(7,1))
b = np.random.randint(1,10,(1,7))
print(a)
print('-------\n\n')
print(b)
# Out:
# [[9]
#  [9]
#  [7]
#  [5]
#  [9]
#  [8]
#  [4]]
# -------
#
#
# [[5 6 8 6 7 4 5]]

# %%
a+b
# Out:
# array([[14, 15, 17, 15, 16, 13, 14],
#        [14, 15, 17, 15, 16, 13, 14],
#        [12, 13, 15, 13, 14, 11, 12],
#        [10, 11, 13, 11, 12,  9, 10],
#        [14, 15, 17, 15, 16, 13, 14],
#        [13, 14, 16, 14, 15, 12, 13],
#        [ 9, 10, 12, 10, 11,  8,  9]])

# %%
a = np.random.randint(1,10,(1,1,5))
b = np.random.randint(1,10,(5,5,5))
print(a)
print('-------\n\n')
print(b)
# Out:
# [[[5 4 6 9 3]]]
# -------
#
#
# [[[4 4 6 4 3]
#   [3 4 9 8 3]
#   [7 5 5 3 9]
#   [3 8 1 5 8]
#   [9 9 9 7 4]]
#
#  [[8 3 5 2 6]
#   [6 6 3 4 1]
#   [2 5 8 9 5]
#   [5 9 3 5 4]
#   [1 4 7 8 4]]
#
#  [[9 2 5 1 6]
#   [6 1 4 5 8]
#   [1 9 7 4 6]
#   [7 3 2 9 2]
#   [6 7 1 6 1]]
#
#  [[1 4 2 8 2]
#   [1 4 5 4 5]
#   [3 8 2 3 5]
#   [7 6 4 3 8]
#   [2 6 9 9 5]]
#
#  [[8 7 9 3 9]
#   [2 5 7 4 1]
#   [1 7 1 4 1]
#   [1 7 4 6 5]
#   [1 6 5 2 2]]]

# %%
a+b
# Out:
# array([[[ 9,  8, 12, 13,  6],
#         [ 8,  8, 15, 17,  6],
#         [12,  9, 11, 12, 12],
#         [ 8, 12,  7, 14, 11],
#         [14, 13, 15, 16,  7]],
#
#        [[13,  7, 11, 11,  9],
#         [11, 10,  9, 13,  4],
#         [ 7,  9, 14, 18,  8],
#         [10, 13,  9, 14,  7],
#         [ 6,  8, 13, 17,  7]],
#
#        [[14,  6, 11, 10,  9],
#         [11,  5, 10, 14, 11],
#         [ 6, 13, 13, 13,  9],
#         [12,  7,  8, 18,  5],
#         [11, 11,  7, 15,  4]],
#
#        [[ 6,  8,  8, 17,  5],
#         [ 6,  8, 11, 13,  8],
#         [ 8, 12,  8, 12,  8],
#         [12, 10, 10, 12, 11],
#         [ 7, 10, 15, 18,  8]],
#
#        [[13, 11, 15, 12, 12],
#         [ 7,  9, 13, 13,  4],
#         [ 6, 11,  7, 13,  4],
#         [ 6, 11, 10, 15,  8],
#         [ 6, 10, 11, 11,  5]]])

# %% [markdown]
# # Introduction to Pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
import numpy as np
import random

products =['Chair','Tables','Laptop','Mobile Phones','Charger']
region = ['East','West','North','South']
all_data =pd.date_range('01-01-2025','23-07-2025')


data = {'Order_ID':range(1,1001),
        'Date':random.choices(all_data,k=1000),
        'Region Name':random.choices(region,k = 1000),
       'Product Name':random.choices(products,k = 1000),
       'Sales':np.random.randint(100,10000,1000),
       'Qty':np.random.randint(1,10,1000),
       'Profit':np.random.randint(-10000,10000,1000)}


table = pd.DataFrame(data)
table
# Out:
#      Order_ID       Date Region Name   Product Name  Sales  Qty  Profit
# 0           1 2025-03-17       North          Chair   5169    6    3006
# 1           2 2025-03-14        East         Laptop   1371    4    9348
# 2           3 2025-06-20       South        Charger   6520    6   -5184
# 3           4 2025-01-31       South          Chair   2954    8   -1503
# 4           5 2025-04-17        West  Mobile Phones   7503    9    4423
# ..        ...        ...         ...            ...    ...  ...     ...
# 995       996 2025-04-10        East         Tables   2619    3    9067
# 996       997 2025-04-01        East         Laptop   2184    5   -1644
# 997       998 2025-04-26       North         Tables   1670    1    6860
# 998       999 2025-05-21        West         Tables   8660    1   -8995
# 999      1000 2025-07-16       South         Tables   3243    1    3933
#
# [1000 rows x 7 columns]

# %%
#Data Column

# %%
all_data =pd.date_range('01-01-2025','23-07-2025')

# %%
#top data (by default shows 5 values)
table.head(10)
# Out:
#    Order_ID       Date Region Name   Product Name  Sales  Qty  Profit
# 0         1 2025-03-17       North          Chair   5169    6    3006
# 1         2 2025-03-14        East         Laptop   1371    4    9348
# 2         3 2025-06-20       South        Charger   6520    6   -5184
# 3         4 2025-01-31       South          Chair   2954    8   -1503
# 4         5 2025-04-17        West  Mobile Phones   7503    9    4423
# 5         6 2025-06-23       North          Chair   8214    9   -2733
# 6         7 2025-06-12       North         Tables   7208    9    6999
# 7         8 2025-07-05        East        Charger    762    9   -7552
# 8         9 2025-05-01       South         Laptop   9190    9   -1745
# 9        10 2025-01-27       South        Charger   6026    6    6784

# %%
#table tail (by default shows 5 values)
table.tail(7)
# Out:
#      Order_ID       Date Region Name   Product Name  Sales  Qty  Profit
# 993       994 2025-05-26        East         Tables   2211    9   -3749
# 994       995 2025-06-30       North  Mobile Phones   3527    2      15
# 995       996 2025-04-10        East         Tables   2619    3    9067
# 996       997 2025-04-01        East         Laptop   2184    5   -1644
# 997       998 2025-04-26       North         Tables   1670    1    6860
# 998       999 2025-05-21        West         Tables   8660    1   -8995
# 999      1000 2025-07-16       South         Tables   3243    1    3933

# %%
table.sample()
# Out:
#      Order_ID       Date Region Name   Product Name  Sales  Qty  Profit
# 623       624 2025-07-05       North  Mobile Phones   2239    8   -7035

# %%
table.sample(5)
# Out:
#      Order_ID       Date Region Name   Product Name  Sales  Qty  Profit
# 298       299 2025-05-16       North          Chair   6857    1    1187
# 602       603 2025-05-22        East          Chair   8891    2     508
# 895       896 2025-04-12       South  Mobile Phones    465    8    -658
# 748       749 2025-01-13       North         Tables   9216    9    4186
# 768       769 2025-05-01        West        Charger   6788    8    1814

# %%
# Information:- about dataset

table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_ID      1000 non-null   int64
#  1   Date          1000 non-null   datetime64[ns]
#  2   Region Name   1000 non-null   object
#  3   Product Name  1000 non-null   object
#  4   Sales         1000 non-null   int32
#  5   Qty           1000 non-null   int32
#  6   Profit        1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
#Columns name

table.columns
# Out:
# Index(['Order_ID', 'Date', 'Region Name', 'Product Name', 'Sales', 'Qty',
#        'Profit'],
#       dtype='object')

# %%
# Index

table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#isna: it will check nan value counts

table.isna()
# Out:
#      Order_ID   Date  Region Name  Product Name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()
# Out:
# Order_ID  Date   Region Name  Product Name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64

# %%
#isnull
table.isnull().value_counts()
# Out:
# Order_ID  Date   Region Name  Product Name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64
